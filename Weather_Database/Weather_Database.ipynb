# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# starting url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | tapes
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | port hardy
# Processing Record 8 of Set 1 | fort nelson
# Processing Record 9 of Set 1 | mehriz
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | cayenne
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | komsomolskiy
# Processing Record 16 of Set 1 | lamar
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | fairmont
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | sao joaquim
# Processing Record 24 of Set 1 | vytegra
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | morki
# Processing Record 27 of Set 1 | tanabe
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | yulara
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | barao de melgaco
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | kununurra
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 1 | tayshet
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | los llanos de aridane
# Processing Record 46 of Set 1 | erdenet
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | kalmunai
# Processing Record 49 of Set 1 | mpongwe
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | caucaia
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | gao
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | sisimiut
# Processing Record 12 of Set 2 | preobrazheniye
# Processing Record 13 of Set 2 | pina
# Processing Record 14 of Set 2 | sao felix do xingu
# Processing Record 15 of Set 2 | myitkyina
# Processing Record 16 of Set 2 | tessalit
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | hirara
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | laguna
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | north bend
# Processing Record 23 of Set 2 | lasa
# Processing Record 24 of Set 2 | copiapo
# Processing Record 25 of Set 2 | pangnirtung
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | ugoofaaru
# Processing Record 28 of Set 2 | sabzevar
# Processing Record 29 of Set 2 | port lincoln
# Processing Record 30 of Set 2 | anloga
# Processing Record 31 of Set 2 | howard springs
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | marshall
# Processing Record 35 of Set 2 | tilichiki
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | mattru
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | kodinsk
# Processing Record 40 of Set 2 | egvekinot
# Processing Record 41 of Set 2 | staryy nadym
# Processing Record 42 of Set 2 | moindou
# Processing Record 43 of Set 2 | villacarrillo
# Processing Record 44 of Set 2 | sorland
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | vila velha
# Processing Record 47 of Set 2 | sabha
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | labuhan
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | cabul-an
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | gus-khrustalnyy
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | harper
# Processing Record 7 of Set 3 | arlit
# Processing Record 8 of Set 3 | kuusamo
# Processing Record 9 of Set 3 | saint anthony
# Processing Record 10 of Set 3 | sao gabriel da cachoeira
# Processing Record 11 of Set 3 | piranshahr
# Processing Record 12 of Set 3 | kolpny
# Processing Record 13 of Set 3 | perevolotskiy
# Processing Record 14 of Set 3 | seoul
# Processing Record 15 of Set 3 | kalamakion
# City not found. Skipping...
# Processing Record 16 of Set 3 | vila
# Processing Record 17 of Set 3 | port blair
# Processing Record 18 of Set 3 | ballina
# Processing Record 19 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | tlaxiaco
# City not found. Skipping...
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | blagoyevo
# Processing Record 24 of Set 3 | timra
# Processing Record 25 of Set 3 | zapolyarnyy
# Processing Record 26 of Set 3 | boksitogorsk
# Processing Record 27 of Set 3 | noyabrsk
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | whyalla
# Processing Record 30 of Set 3 | buchanan
# Processing Record 31 of Set 3 | cabra
# Processing Record 32 of Set 3 | alofi
# Processing Record 33 of Set 3 | north platte
# Processing Record 34 of Set 3 | erdemli
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | portland
# Processing Record 37 of Set 3 | meulaboh
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | khed brahma
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | sur
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | novaya igirma
# Processing Record 44 of Set 3 | nesna
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | narasannapeta
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | humboldt
# Processing Record 49 of Set 3 | hilo
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | isangel
# Processing Record 5 of Set 4 | rundu
# Processing Record 6 of Set 4 | shitanjing
# Processing Record 7 of Set 4 | otane
# Processing Record 8 of Set 4 | ust-nera
# Processing Record 9 of Set 4 | santa teresa
# Processing Record 10 of Set 4 | yataity
# Processing Record 11 of Set 4 | auki
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | rabak
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | sajanan
# Processing Record 16 of Set 4 | iqaluit
# Processing Record 17 of Set 4 | okha
# Processing Record 18 of Set 4 | anadyr
# Processing Record 19 of Set 4 | bilma
# Processing Record 20 of Set 4 | mbuji-mayi
# Processing Record 21 of Set 4 | vestmannaeyjar
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | santa fe
# Processing Record 24 of Set 4 | vaini
# Processing Record 25 of Set 4 | kudahuvadhoo
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | itoman
# Processing Record 28 of Set 4 | parfenyevo
# Processing Record 29 of Set 4 | coihaique
# Processing Record 30 of Set 4 | olavarria
# Processing Record 31 of Set 4 | talnakh
# Processing Record 32 of Set 4 | camacupa
# Processing Record 33 of Set 4 | espanola
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | huilong
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | kanye
# Processing Record 40 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 41 of Set 4 | kouroussa
# Processing Record 42 of Set 4 | uvalde
# Processing Record 43 of Set 4 | rincon
# Processing Record 44 of Set 4 | tonj
# Processing Record 45 of Set 4 | raymondville
# Processing Record 46 of Set 4 | taksimo
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | muzhi
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | chokurdakh
# Processing Record 1 of Set 5 | kijang
# Processing Record 2 of Set 5 | huicheng
# Processing Record 3 of Set 5 | leningradskiy
# Processing Record 4 of Set 5 | dingle
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | nhamunda
# Processing Record 7 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 5 | nouakchott
# Processing Record 9 of Set 5 | alvorada
# Processing Record 10 of Set 5 | zhigansk
# Processing Record 11 of Set 5 | mahebourg
# Processing Record 12 of Set 5 | takoradi
# Processing Record 13 of Set 5 | bara
# Processing Record 14 of Set 5 | marquette
# Processing Record 15 of Set 5 | waitati
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | awjilah
# Processing Record 18 of Set 5 | nome
# Processing Record 19 of Set 5 | yarada
# Processing Record 20 of Set 5 | datong
# Processing Record 21 of Set 5 | port-gentil
# Processing Record 22 of Set 5 | matagami
# Processing Record 23 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | kieta
# Processing Record 26 of Set 5 | erzin
# Processing Record 27 of Set 5 | bredasdorp
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | san quintin
# Processing Record 31 of Set 5 | chunskiy
# Processing Record 32 of Set 5 | puerto ayora
# Processing Record 33 of Set 5 | key west
# Processing Record 34 of Set 5 | imperia
# Processing Record 35 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 5 | marawi
# Processing Record 37 of Set 5 | goderich
# Processing Record 38 of Set 5 | harstad
# Processing Record 39 of Set 5 | khorixas
# Processing Record 40 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 41 of Set 5 | fairlie
# Processing Record 42 of Set 5 | nexo
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | gorontalo
# Processing Record 45 of Set 5 | saint-philippe
# Processing Record 46 of Set 5 | westport
# Processing Record 47 of Set 5 | hede
# Processing Record 48 of Set 5 | college
# Processing Record 49 of Set 5 | raudeberg
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | jiuquan
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 6 | mitsamiouli
# Processing Record 5 of Set 6 | gewane
# Processing Record 6 of Set 6 | viedma
# Processing Record 7 of Set 6 | inhambane
# Processing Record 8 of Set 6 | hanzhong
# Processing Record 9 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 6 | tanout
# Processing Record 11 of Set 6 | homer
# Processing Record 12 of Set 6 | lorengau
# Processing Record 13 of Set 6 | san juan
# Processing Record 14 of Set 6 | beringovskiy
# Processing Record 15 of Set 6 | karasburg
# Processing Record 16 of Set 6 | soligalich
# Processing Record 17 of Set 6 | takayama
# Processing Record 18 of Set 6 | tafresh
# Processing Record 19 of Set 6 | yaan
# Processing Record 20 of Set 6 | havre-saint-pierre
# Processing Record 21 of Set 6 | manaure
# Processing Record 22 of Set 6 | east london
# Processing Record 23 of Set 6 | ceres
# Processing Record 24 of Set 6 | feijo
# Processing Record 25 of Set 6 | zambezi
# Processing Record 26 of Set 6 | hailey
# Processing Record 27 of Set 6 | pemangkat
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | alamos
# Processing Record 31 of Set 6 | am timan
# Processing Record 32 of Set 6 | filadelfia
# Processing Record 33 of Set 6 | provideniya
# Processing Record 34 of Set 6 | esquipulas
# Processing Record 35 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 36 of Set 6 | torbay
# Processing Record 37 of Set 6 | saint-georges
# Processing Record 38 of Set 6 | fare
# Processing Record 39 of Set 6 | vyartsilya
# Processing Record 40 of Set 6 | bambous virieux
# Processing Record 41 of Set 6 | resende
# Processing Record 42 of Set 6 | lincoln
# Processing Record 43 of Set 6 | ixtepec
# Processing Record 44 of Set 6 | marathon
# Processing Record 45 of Set 6 | chumikan
# Processing Record 46 of Set 6 | birao
# Processing Record 47 of Set 6 | synya
# Processing Record 48 of Set 6 | deep river
# Processing Record 49 of Set 6 | ulladulla
# Processing Record 50 of Set 6 | sinegorskiy
# Processing Record 1 of Set 7 | broome
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | touros
# Processing Record 4 of Set 7 | el badari
# City not found. Skipping...
# Processing Record 5 of Set 7 | toyooka
# Processing Record 6 of Set 7 | youghal
# Processing Record 7 of Set 7 | angoche
# Processing Record 8 of Set 7 | sakakah
# Processing Record 9 of Set 7 | pyay
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | balykshi
# Processing Record 12 of Set 7 | arvin
# Processing Record 13 of Set 7 | altayskoye
# Processing Record 14 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 7 | half moon bay
# Processing Record 16 of Set 7 | itaituba
# Processing Record 17 of Set 7 | makinsk
# Processing Record 18 of Set 7 | puerto del rosario
# Processing Record 19 of Set 7 | belozerskoye
# Processing Record 20 of Set 7 | clovis
# Processing Record 21 of Set 7 | voznesenye
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | san andres
# Processing Record 24 of Set 7 | mahibadhoo
# Processing Record 25 of Set 7 | uromi
# Processing Record 26 of Set 7 | avera
# Processing Record 27 of Set 7 | leshukonskoye
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | marzuq
# Processing Record 30 of Set 7 | qabis
# City not found. Skipping...
# Processing Record 31 of Set 7 | muros
# Processing Record 32 of Set 7 | smirnykh
# Processing Record 33 of Set 7 | magadan
# Processing Record 34 of Set 7 | pangoa
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | noumea
# Processing Record 37 of Set 7 | chernyshevskiy
# Processing Record 38 of Set 7 | atbasar
# Processing Record 39 of Set 7 | charters towers
# Processing Record 40 of Set 7 | kuytun
# Processing Record 41 of Set 7 | tazovskiy
# Processing Record 42 of Set 7 | shimoda
# Processing Record 43 of Set 7 | nojorid
# Processing Record 44 of Set 7 | impfondo
# Processing Record 45 of Set 7 | jackson
# Processing Record 46 of Set 7 | garowe
# Processing Record 47 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 7 | winnemucca
# Processing Record 49 of Set 7 | poum
# Processing Record 50 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 1 of Set 8 | comodoro rivadavia
# Processing Record 2 of Set 8 | maniitsoq
# Processing Record 3 of Set 8 | flinders
# Processing Record 4 of Set 8 | potosi
# Processing Record 5 of Set 8 | guerrero negro
# Processing Record 6 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 7 of Set 8 | bagnols-sur-ceze
# Processing Record 8 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 8 | tura
# Processing Record 10 of Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 11 of Set 8 | vanimo
# Processing Record 12 of Set 8 | havelock
# Processing Record 13 of Set 8 | san patricio
# Processing Record 14 of Set 8 | maldonado
# Processing Record 15 of Set 8 | minab
# Processing Record 16 of Set 8 | mulege
# Processing Record 17 of Set 8 | airai
# Processing Record 18 of Set 8 | bodrum
# Processing Record 19 of Set 8 | halifax
# Processing Record 20 of Set 8 | sawtell
# Processing Record 21 of Set 8 | aksu
# Processing Record 22 of Set 8 | dalvik
# Processing Record 23 of Set 8 | namibe
# Processing Record 24 of Set 8 | tual
# Processing Record 25 of Set 8 | snasa
# Processing Record 26 of Set 8 | quatre cocos
# Processing Record 27 of Set 8 | otorohanga
# Processing Record 28 of Set 8 | hohhot
# Processing Record 29 of Set 8 | ilulissat
# Processing Record 30 of Set 8 | omboue
# Processing Record 31 of Set 8 | taltal
# Processing Record 32 of Set 8 | sibolga
# Processing Record 33 of Set 8 | dickinson
# Processing Record 34 of Set 8 | cedar city
# Processing Record 35 of Set 8 | camara de lobos
# Processing Record 36 of Set 8 | sioux lookout
# Processing Record 37 of Set 8 | shirak
# Processing Record 38 of Set 8 | kamaishi
# Processing Record 39 of Set 8 | svetlyy
# Processing Record 40 of Set 8 | namtsy
# Processing Record 41 of Set 8 | ahuimanu
# Processing Record 42 of Set 8 | kahama
# Processing Record 43 of Set 8 | manta
# Processing Record 44 of Set 8 | nelson bay
# Processing Record 45 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 46 of Set 8 | onega
# Processing Record 47 of Set 8 | kloulklubed
# Processing Record 48 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 8 | uk
# City not found. Skipping...
# Processing Record 50 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | mahon
# Processing Record 2 of Set 9 | makakilo city
# Processing Record 3 of Set 9 | luena
# Processing Record 4 of Set 9 | praia da vitoria
# Processing Record 5 of Set 9 | hambantota
# Processing Record 6 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 9 | zavallya
# Processing Record 8 of Set 9 | port hawkesbury
# Processing Record 9 of Set 9 | kavaratti
# Processing Record 10 of Set 9 | roseburg
# Processing Record 11 of Set 9 | loviisa
# Processing Record 12 of Set 9 | roebourne
# Processing Record 13 of Set 9 | la solana
# Processing Record 14 of Set 9 | suruc
# Processing Record 15 of Set 9 | marmora
# Processing Record 16 of Set 9 | zafra
# Processing Record 17 of Set 9 | santa maria
# Processing Record 18 of Set 9 | genhe
# Processing Record 19 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 9 | novo aripuana
# Processing Record 21 of Set 9 | gohpur
# Processing Record 22 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 23 of Set 9 | palau
# Processing Record 24 of Set 9 | biltine
# Processing Record 25 of Set 9 | la libertad
# Processing Record 26 of Set 9 | rio branco
# Processing Record 27 of Set 9 | tokur
# Processing Record 28 of Set 9 | bud
# Processing Record 29 of Set 9 | benguela
# Processing Record 30 of Set 9 | belchatow
# Processing Record 31 of Set 9 | kahramanmaras
# Processing Record 32 of Set 9 | aripuana
# Processing Record 33 of Set 9 | urozhaynoye
# Processing Record 34 of Set 9 | bereznik
# Processing Record 35 of Set 9 | linjiang
# Processing Record 36 of Set 9 | ha tinh
# Processing Record 37 of Set 9 | vao
# Processing Record 38 of Set 9 | volchikha
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | gamba
# Processing Record 41 of Set 9 | grong
# Processing Record 42 of Set 9 | digby
# Processing Record 43 of Set 9 | mandurah
# Processing Record 44 of Set 9 | ola
# Processing Record 45 of Set 9 | hamilton
# Processing Record 46 of Set 9 | korla
# Processing Record 47 of Set 9 | grand gaube
# Processing Record 48 of Set 9 | challans
# Processing Record 49 of Set 9 | praia
# Processing Record 50 of Set 9 | esmeraldas
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | saint-pierre
# Processing Record 3 of Set 10 | pozo colorado
# Processing Record 4 of Set 10 | kharp
# Processing Record 5 of Set 10 | berlevag
# Processing Record 6 of Set 10 | sitka
# Processing Record 7 of Set 10 | faanui
# Processing Record 8 of Set 10 | faya
# Processing Record 9 of Set 10 | belaya gora
# Processing Record 10 of Set 10 | nichinan
# Processing Record 11 of Set 10 | bonavista
# Processing Record 12 of Set 10 | karasjok
# Processing Record 13 of Set 10 | grindavik
# Processing Record 14 of Set 10 | sabang
# Processing Record 15 of Set 10 | itanhandu
# Processing Record 16 of Set 10 | ust-omchug
# Processing Record 17 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 18 of Set 10 | adeje
# Processing Record 19 of Set 10 | iquitos
# Processing Record 20 of Set 10 | balabac
# Processing Record 21 of Set 10 | bandarbeyla
# Processing Record 22 of Set 10 | mae sai
# Processing Record 23 of Set 10 | jimo
# Processing Record 24 of Set 10 | severo-kurilsk
# Processing Record 25 of Set 10 | saint-malo
# Processing Record 26 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 10 | warragul
# Processing Record 28 of Set 10 | san joaquin
# Processing Record 29 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 10 | aleksandro-nevskiy
# Processing Record 32 of Set 10 | jalapa
# Processing Record 33 of Set 10 | seinajoki
# Processing Record 34 of Set 10 | piet retief
# Processing Record 35 of Set 10 | brasilia
# Processing Record 36 of Set 10 | bongor
# Processing Record 37 of Set 10 | nenjiang
# Processing Record 38 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 39 of Set 10 | labytnangi
# Processing Record 40 of Set 10 | kembe
# Processing Record 41 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 10 | pacific grove
# Processing Record 43 of Set 10 | novopokrovka
# Processing Record 44 of Set 10 | cherskiy
# Processing Record 45 of Set 10 | chalus
# Processing Record 46 of Set 10 | yar-sale
# Processing Record 47 of Set 10 | caravelas
# Processing Record 48 of Set 10 | besikduzu
# Processing Record 49 of Set 10 | emba
# Processing Record 50 of Set 10 | ndele
# Processing Record 1 of Set 11 | saint-quentin
# Processing Record 2 of Set 11 | tawau
# Processing Record 3 of Set 11 | malabor
# Processing Record 4 of Set 11 | novopskov
# Processing Record 5 of Set 11 | ayan
# Processing Record 6 of Set 11 | chumphon
# Processing Record 7 of Set 11 | kholm-zhirkovskiy
# Processing Record 8 of Set 11 | kholtoson
# Processing Record 9 of Set 11 | gravdal
# Processing Record 10 of Set 11 | descalvado
# Processing Record 11 of Set 11 | pringsewu
# Processing Record 12 of Set 11 | tlahualilo
# City not found. Skipping...
# Processing Record 13 of Set 11 | tam ky
# Processing Record 14 of Set 11 | barcelos
# Processing Record 15 of Set 11 | lensk
# Processing Record 16 of Set 11 | djibo
# Processing Record 17 of Set 11 | almeria
# Processing Record 18 of Set 11 | margate
# Processing Record 19 of Set 11 | koumac
# Processing Record 20 of Set 11 | ewa beach
# Processing Record 21 of Set 11 | rahden
# Processing Record 22 of Set 11 | umm kaddadah
# Processing Record 23 of Set 11 | jingdezhen
# Processing Record 24 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 11 | disna
# Processing Record 27 of Set 11 | lata
# Processing Record 28 of Set 11 | nauchnyy gorodok
# Processing Record 29 of Set 11 | zhangye
# Processing Record 30 of Set 11 | chahal
# Processing Record 31 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 11 | bardiyah
# Processing Record 34 of Set 11 | kudymkar
# Processing Record 35 of Set 11 | yarmouth
# Processing Record 36 of Set 11 | alvand
# Processing Record 37 of Set 11 | marsh harbour
# Processing Record 38 of Set 11 | darhan
# Processing Record 39 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 40 of Set 11 | katsuura
# Processing Record 41 of Set 11 | tres arroyos
# Processing Record 42 of Set 11 | bilibino
# Processing Record 43 of Set 11 | saint leonard
# Processing Record 44 of Set 11 | eureka
# Processing Record 45 of Set 11 | aitape
# Processing Record 46 of Set 11 | brae
# Processing Record 47 of Set 11 | nuuk
# Processing Record 48 of Set 11 | layou
# Processing Record 49 of Set 11 | alyangula
# Processing Record 50 of Set 11 | gaoual
# Processing Record 1 of Set 12 | catamarca
# Processing Record 2 of Set 12 | coxim
# Processing Record 3 of Set 12 | itarema
# Processing Record 4 of Set 12 | waddan
# Processing Record 5 of Set 12 | mithi
# Processing Record 6 of Set 12 | ankang
# Processing Record 7 of Set 12 | mounana
# Processing Record 8 of Set 12 | geraldton
# Processing Record 9 of Set 12 | cabedelo
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | chunhuhub
# Processing Record 12 of Set 12 | valparaiso
# Processing Record 13 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 14 of Set 12 | melfi
# Processing Record 15 of Set 12 | talara
# Processing Record 16 of Set 12 | virginia beach
# Processing Record 17 of Set 12 | koundara
# Processing Record 18 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 19 of Set 12 | whitianga
# Processing Record 20 of Set 12 | puli
# Processing Record 21 of Set 12 | ewo
# Processing Record 22 of Set 12 | siolim
# City not found. Skipping...
# Processing Record 23 of Set 12 | paris
# Processing Record 24 of Set 12 | opuwo
# Processing Record 25 of Set 12 | esperance
# Processing Record 26 of Set 12 | lerwick
# Processing Record 27 of Set 12 | campana
# Processing Record 28 of Set 12 | chikwawa
# Processing Record 29 of Set 12 | kutum
# Processing Record 30 of Set 12 | kautokeino
# Processing Record 31 of Set 12 | chilca
# Processing Record 32 of Set 12 | sigli
# Processing Record 33 of Set 12 | middle island
# Processing Record 34 of Set 12 | urumqi
# Processing Record 35 of Set 12 | lumphat
# Processing Record 36 of Set 12 | eldoret
# Processing Record 37 of Set 12 | velikiy ustyug
# Processing Record 38 of Set 12 | maceio
# Processing Record 39 of Set 12 | erenhot
# Processing Record 40 of Set 12 | beaupre
# Processing Record 41 of Set 12 | ambilobe
# Processing Record 42 of Set 12 | bajil
# Processing Record 43 of Set 12 | myrtle beach
# Processing Record 44 of Set 12 | shirokiy
# Processing Record 45 of Set 12 | inongo
# Processing Record 46 of Set 12 | maskinonge
# Processing Record 47 of Set 12 | igarka
# Processing Record 48 of Set 12 | albertville
# Processing Record 49 of Set 12 | anshun
# Processing Record 50 of Set 12 | bundaberg
# Processing Record 1 of Set 13 | katangli
# Processing Record 2 of Set 13 | ugleuralskiy
# Processing Record 3 of Set 13 | thung song
# Processing Record 4 of Set 13 | daru
# Processing Record 5 of Set 13 | lakatoro
# Processing Record 6 of Set 13 | loa janan
# Processing Record 7 of Set 13 | christchurch
# Processing Record 8 of Set 13 | maralal
# Processing Record 9 of Set 13 | tuatapere
# Processing Record 10 of Set 13 | launceston
# Processing Record 11 of Set 13 | bayir
# Processing Record 12 of Set 13 | husavik
# Processing Record 13 of Set 13 | clyde
# Processing Record 14 of Set 13 | nouadhibou
# Processing Record 15 of Set 13 | tinskoy
# Processing Record 16 of Set 13 | vaxjo
# Processing Record 17 of Set 13 | harsin
# Processing Record 18 of Set 13 | burica
# City not found. Skipping...
# Processing Record 19 of Set 13 | yeppoon
# Processing Record 20 of Set 13 | vardo
# Processing Record 21 of Set 13 | oranjemund
# Processing Record 22 of Set 13 | samarai
# Processing Record 23 of Set 13 | martapura
# Processing Record 24 of Set 13 | kemin
# Processing Record 25 of Set 13 | buraydah
# Processing Record 26 of Set 13 | moose factory
# Processing Record 27 of Set 13 | cascais
# Processing Record 28 of Set 13 | nanortalik
# Processing Record 29 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 13 | yoichi
# Processing Record 31 of Set 13 | vila franca do campo
# Processing Record 32 of Set 13 | forrest city
# Processing Record 33 of Set 13 | jalu
# Processing Record 34 of Set 13 | thompson
# Processing Record 35 of Set 13 | romny
# Processing Record 36 of Set 13 | is
# City not found. Skipping...
# Processing Record 37 of Set 13 | antofagasta
# Processing Record 38 of Set 13 | slobodskoy
# Processing Record 39 of Set 13 | saurimo
# Processing Record 40 of Set 13 | marica
# Processing Record 41 of Set 13 | olafsvik
# Processing Record 42 of Set 13 | hokitika
# Processing Record 43 of Set 13 | etaples
# Processing Record 44 of Set 13 | ust-maya
# Processing Record 45 of Set 13 | shelburne
# Processing Record 46 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 13 | keti bandar
# Processing Record 48 of Set 13 | shenjiamen
# Processing Record 49 of Set 13 | beloha
# Processing Record 50 of Set 13 | craig
# Processing Record 1 of Set 14 | sobolevo
# Processing Record 2 of Set 14 | marystown
# Processing Record 3 of Set 14 | sungairaya
# Processing Record 4 of Set 14 | masvingo
# Processing Record 5 of Set 14 | ndjole
# Processing Record 6 of Set 14 | rawson
# Processing Record 7 of Set 14 | necochea
# Processing Record 8 of Set 14 | padang
# Processing Record 9 of Set 14 | vila do maio
# Processing Record 10 of Set 14 | nyurba
# Processing Record 11 of Set 14 | srednekolymsk
# Processing Record 12 of Set 14 | lodja
# Processing Record 13 of Set 14 | maryville
# Processing Record 14 of Set 14 | soderhamn
# Processing Record 15 of Set 14 | baneh
# Processing Record 16 of Set 14 | kosikha
# Processing Record 17 of Set 14 | mount isa
# Processing Record 18 of Set 14 | jalingo
# Processing Record 19 of Set 14 | talcahuano
# Processing Record 20 of Set 14 | wajima
# Processing Record 21 of Set 14 | la ronge
# Processing Record 22 of Set 14 | velika gorica
# Processing Record 23 of Set 14 | aykhal
# Processing Record 24 of Set 14 | toora-khem
# Processing Record 25 of Set 14 | alto araguaia
# Processing Record 26 of Set 14 | shorapur
# Processing Record 27 of Set 14 | mikuni
# Processing Record 28 of Set 14 | byron bay
# Processing Record 29 of Set 14 | goure
# Processing Record 30 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 14 | sedan
# Processing Record 32 of Set 14 | roald
# Processing Record 33 of Set 14 | saint-joseph
# Processing Record 34 of Set 14 | aksehir
# Processing Record 35 of Set 14 | calabozo
# Processing Record 36 of Set 14 | manakara
# Processing Record 37 of Set 14 | kapoeta
# Processing Record 38 of Set 14 | owensboro
# Processing Record 39 of Set 14 | shepsi
# Processing Record 40 of Set 14 | petropavlovka
# Processing Record 41 of Set 14 | suao
# City not found. Skipping...
# Processing Record 42 of Set 14 | banswara
# Processing Record 43 of Set 14 | guatire
# Processing Record 44 of Set 14 | qaqortoq
# Processing Record 45 of Set 14 | tver
# Processing Record 46 of Set 14 | klaksvik
# Processing Record 47 of Set 14 | suphan buri
# Processing Record 48 of Set 14 | neiafu
# Processing Record 49 of Set 14 | rocha
# Processing Record 50 of Set 14 | bonthe
# Processing Record 1 of Set 15 | daudnagar
# Processing Record 2 of Set 15 | tambul
# City not found. Skipping...
# Processing Record 3 of Set 15 | inhumas
# Processing Record 4 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 15 | upata
# Processing Record 6 of Set 15 | morros
# Processing Record 7 of Set 15 | seymchan
# Processing Record 8 of Set 15 | liverpool
# Processing Record 9 of Set 15 | santacruz
# Processing Record 10 of Set 15 | hualmay
# Processing Record 11 of Set 15 | tshikapa
# Processing Record 12 of Set 15 | pitimbu
# Processing Record 13 of Set 15 | dwarka
# Processing Record 14 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 15 | gazli
# Processing Record 16 of Set 15 | gat
# Processing Record 17 of Set 15 | moche
# Processing Record 18 of Set 15 | trelew
# Processing Record 19 of Set 15 | hervey bay
# Processing Record 20 of Set 15 | labelle
# Processing Record 21 of Set 15 | gemena
# Processing Record 22 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 15 | aljezur
# Processing Record 25 of Set 15 | yeniseysk
# Processing Record 26 of Set 15 | muzquiz
# City not found. Skipping...
# Processing Record 27 of Set 15 | baykit
# Processing Record 28 of Set 15 | tsiroanomandidy
# Processing Record 29 of Set 15 | araouane
# Processing Record 30 of Set 15 | wanning
# Processing Record 31 of Set 15 | freeport
# Processing Record 32 of Set 15 | waingapu
# Processing Record 33 of Set 15 | saint-francois
# Processing Record 34 of Set 15 | codrington
# Processing Record 35 of Set 15 | shubarkuduk
# Processing Record 36 of Set 15 | walvis bay
# Processing Record 37 of Set 15 | lavrentiya
# Processing Record 38 of Set 15 | kropotkin
# Processing Record 39 of Set 15 | tabuk
# Processing Record 40 of Set 15 | san rafael
# Processing Record 41 of Set 15 | kayanza
# Processing Record 42 of Set 15 | sibu
# Processing Record 43 of Set 15 | paamiut
# Processing Record 44 of Set 15 | gizo
# Processing Record 45 of Set 15 | turayf
# Processing Record 46 of Set 15 | luwuk
# Processing Record 47 of Set 15 | paine
# Processing Record 48 of Set 15 | yithion
# City not found. Skipping...
# Processing Record 49 of Set 15 | aichach
# Processing Record 50 of Set 15 | maltahohe
# Processing Record 1 of Set 16 | ambon
# Processing Record 2 of Set 16 | ko samui
# Processing Record 3 of Set 16 | verkhnetulomskiy
# Processing Record 4 of Set 16 | shache
# Processing Record 5 of Set 16 | popondetta
# Processing Record 6 of Set 16 | sept-iles
# Processing Record 7 of Set 16 | atar
# Processing Record 8 of Set 16 | ngunguru
# Processing Record 9 of Set 16 | vallenar
# Processing Record 10 of Set 16 | makamba
# Processing Record 11 of Set 16 | kajiado
# Processing Record 12 of Set 16 | asau
# Processing Record 13 of Set 16 | xai-xai
# Processing Record 14 of Set 16 | qandala
# Processing Record 15 of Set 16 | roros
# Processing Record 16 of Set 16 | gillette
# Processing Record 17 of Set 16 | la union
# Processing Record 18 of Set 16 | chardara
# Processing Record 19 of Set 16 | sarkand
# Processing Record 20 of Set 16 | parabel
# Processing Record 21 of Set 16 | jabinyanah
# Processing Record 22 of Set 16 | crabtree
# Processing Record 23 of Set 16 | baley
# Processing Record 24 of Set 16 | kokoda
# Processing Record 25 of Set 16 | missoula
# Processing Record 26 of Set 16 | bubaque
# Processing Record 27 of Set 16 | trat
# Processing Record 28 of Set 16 | kendari
# Processing Record 29 of Set 16 | lahat
# Processing Record 30 of Set 16 | kasamwa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
# convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Norman Wells      CA  65.2820 -126.8329     26.64        93          75
# 1       Rikitea      PF -23.1203 -134.9692     73.49        79         100
# 2    Georgetown      MY   5.4112  100.3354     76.98        91          40
# 3         Tapes      BR -30.6733  -51.3958     70.90        61          41
# 4    Nikolskoye      RU  59.7035   30.7861     55.02        66          54
# 5    Port Hardy      CA  50.6996 -127.4199     47.66        86         100
# 6   Fort Nelson      CA  58.8053 -122.7002     29.79        93          90
# 7        Mehriz      IR  31.5917   54.4318     75.70        17           0
# 8       Ushuaia      AR -54.8000  -68.3000     49.66        53          40
# 9  Punta Arenas      CL -53.1500  -70.9167     51.91        54          40
#
#    Wind Speed Current Description
# 0        5.75          light snow
# 1       18.45          light rain
# 2        5.01    scattered clouds
# 3       12.17    scattered clouds
# 4       12.50       broken clouds
# 5        1.81          light rain
# 6        2.30          light snow
# 7        0.63           clear sky
# 8        4.61    scattered clouds
# 9       28.77    scattered clouds

# %%
# Reorder columns
new_column_order = ['City', 'Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Norman Wells      CA  65.2820 -126.8329     26.64        93          75
# 1       Rikitea      PF -23.1203 -134.9692     73.49        79         100
# 2    Georgetown      MY   5.4112  100.3354     76.98        91          40
# 3         Tapes      BR -30.6733  -51.3958     70.90        61          41
# 4    Nikolskoye      RU  59.7035   30.7861     55.02        66          54
# 5    Port Hardy      CA  50.6996 -127.4199     47.66        86         100
# 6   Fort Nelson      CA  58.8053 -122.7002     29.79        93          90
# 7        Mehriz      IR  31.5917   54.4318     75.70        17           0
# 8       Ushuaia      AR -54.8000  -68.3000     49.66        53          40
# 9  Punta Arenas      CL -53.1500  -70.9167     51.91        54          40
#
#    Wind Speed Current Description
# 0        5.75          light snow
# 1       18.45          light rain
# 2        5.01    scattered clouds
# 3       12.17    scattered clouds
# 4       12.50       broken clouds
# 5        1.81          light rain
# 6        2.30          light snow
# 7        0.63           clear sky
# 8        4.61    scattered clouds
# 9       28.77    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
